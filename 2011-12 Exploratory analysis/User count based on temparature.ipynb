# %%
import pandas as pd
import numpy as np
import statistics as st
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import savefig
# %matplotlib inline
import datetime

# %%
day_data = pd.read_csv(r"C:\Users\Sheikh Nabil\Anaconda\Desktop\capital-bike-share\2011-12 Exploratory analysis\data set\day.csv")

# %%
day_data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
cal_feel = day_data['atemp']*47 - 8
cal_feel
# Out:
# 0      9.090375
# 1      8.625733
# 2      0.902035
# 3      1.969734
# 4      2.775690
#          ...
# 726    2.652174
# 727    3.987162
# 728    3.392800
# 729    2.889900
# 730    2.503889
# Name: atemp, Length: 731, dtype: float64

# %%
cal_feel = np.ceil(cal_feel)

# %%
day_data.insert(11, column= 'cal_feel', value= cal_feel)
day_data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp  cal_feel       hum  windspeed  casual  \
# ...

# %%
day_data.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp    cal_feel         hum  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354   14.785226    0.627894
# ...

# %%
day_data['temp_level'] = day_data['cal_feel'].apply(lambda value: 'low'
if value <= 8 else 'medium'
if value <= 20 else 'high')
day_data['temp_level'] = pd.Categorical(day_data['temp_level'],
categories=['low', 'medium', 'high'])

# %%
day_data
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp  cal_feel       hum  windspeed  casual  \
# ...

# %%
day_data.loc[day_data['yr'] == 0, 'yr'] = '2011'
day_data.loc[day_data['yr'] ==1, 'yr'] = '2012'

# %%
ax  = sns.barplot(x= 'temp_level', y='casual', hue='yr', data=day_data, ci=None)
# sns.set(style="whitegrid")

# ax.set_ylabel('Count', fontsize=20)
# ax.set_xlabel('Temperature Label', fontsize=20)

# plt.setp(ax.ax_legend().ax_texts(), fontsize='15') # for leaxend text
# plt.setp(ax.ax_legend().ax_title(), fontsize='15'); # for leaxend title

# handles, labels = ax.get_legend_handles_labels()
# ax.legend(handles=handles[1:], labels=labels[1:], title="Whatever else")

day_data.loc[day_data['yr'] == 0, 'yr'] = '2011'
day_data.loc[day_data['yr'] ==1, 'yr'] = '2012'

ax.set_ylabel('Count', fontsize=20)
ax.set_xlabel('Temperature Label', fontsize=20)

# sns.set(style="whitegrid")

# legend = ax.legend()
# legend.texts[-1].set_text("Whatever else")

# handles, labels = ax.get_legend_handles_labels()
# ax.legend(handles=handles[1:], labels=labels[1:])

# handles, labels = ax.get_legend_handles_labels()
# ax.legend(handles=handles[1:], labels=labels[1:], title="Whatever else")
ax.legend().set_title('Year')
# ax.legend().set_title('Year')
plt.setp(ax.get_legend().get_title(), fontsize='5'); # for legend title
plt.legend(loc='upper center');

# %%
ax = sns.barplot(x= 'temp_level', y='registered', hue='yr', data=day_data, ci=None)

day_data.loc[day_data['yr'] == 0, 'yr'] = '2011'
day_data.loc[day_data['yr'] ==1, 'yr'] = '2012'

ax.set_ylabel('registered', fontsize=20)
ax.set_xlabel('Temperature Label', fontsize=20)

plt.legend(loc='upper center')
ax.legend().set_title('Year')
